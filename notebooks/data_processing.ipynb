isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 775 entries, 2022-01-03 to 2024-12-31
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (SAN, Open)       753 non-null    float64
#  1   (SAN, High)       753 non-null    float64
#  2   (SAN, Low)        753 non-null    float64
#  3   (SAN, Close)      753 non-null    float64
#  4   (SAN, Volume)     753 non-null    float64
#  5   (IBE.MC, Open)    768 non-null    float64
#  6   (IBE.MC, High)    768 non-null    float64
#  7   (IBE.MC, Low)     768 non-null    float64
#  8   (IBE.MC, Close)   768 non-null    float64
#  9   (IBE.MC, Volume)  768 non-null    float64
#  10  (SIE.DE, Open)    766 non-null    float64
#  11  (SIE.DE, High)    766 non-null    float64
#  12  (SIE.DE, Low)     766 non-null    float64
#  13  (SIE.DE, Close)   766 non-null    float64
#  14  (SIE.DE, Volume)  766 non-null    float64
#  15  (ITX.MC, Open)    768 non-null    float64
#  16  (ITX.MC, High)    768 non-null    float64
#  17  (ITX.MC, Low)     768 non-null    float64
#  18  (ITX.MC, Close)   768 non-null    float64
#  19  (ITX.MC, Volume)  768 non-null    float64
#  20  (AIR.PA, Open)    768 non-null    float64
#  21  (AIR.PA, High)    768 non-null    float64
#  22  (AIR.PA, Low)     768 non-null    float64
#  23  (AIR.PA, Close)   768 non-null    float64
#  24  (AIR.PA, Volume)  768 non-null    float64
# dtypes: float64(25)
# memory usage: 157.4+ KB
# Ticker  Price
# SAN     Open      22
#         High      22
#         Low       22
#         Close     22
#         Volume    22
# IBE.MC  Open       7
#         High       7
#         Low        7
#         Close      7
#         Volume     7
# SIE.DE  Open       9
#         High       9
#         Low        9
#         Close      9
#         Volume     9
# ITX.MC  Open       7
#         High       7
#         Low        7
#         Close      7
#         Volume     7
# AIR.PA  Open       7
#         High       7
#         Low        7
#         Close      7
#         Volume     7
# dtype: int64

# %% [markdown]
# The *historical_stock.csv* file has 775 entries, from **2022-01-01** to **2025-01-01**. It is easyly observable that at least 7 days are null in every column, those days need to be assessed, as well as some other faulty registries clearly shown in the information above.

# %%
null_dates = df.isnull()

null_dates = null_dates[null_dates.any(axis=1)]
null_dates = null_dates.index.tolist()
print(null_dates)
print(f"Number of null dates: {len(null_dates)}")
print(f"Percentage of null dates: {len(null_dates)/len(df)*100:.2f}%")
# Out:
# ['2022-01-17', '2022-02-21', '2022-04-18', '2022-05-30', '2022-06-20', '2022-07-04', '2022-09-05', '2022-11-24', '2023-01-02', '2023-01-16', '2023-02-20', '2023-04-10', '2023-05-01', '2023-05-29', '2023-06-19', '2023-07-04', '2023-09-04', '2023-11-23', '2023-12-26', '2024-01-15', '2024-02-19', '2024-04-01', '2024-05-01', '2024-05-27', '2024-06-19', '2024-07-04', '2024-09-02', '2024-11-28', '2024-12-24', '2024-12-26', '2024-12-31']
# Number of null dates: 31
# Percentage of null dates: 4.00%

# %% [markdown]
# Being the percentage of null dates as low as $4\%$, these registries can be deleted without compromising the integrity of this study.

# %%
df.dropna(inplace=True)
