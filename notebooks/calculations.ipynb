# %% [markdown]
# ## DAILY RETURNS

# %% [markdown]
# In this section we calculate daily logarithmic returns as well as the covariance matrix of said returns.

# %%
import sys
import os

parent_dir = os.path.abspath('..')

if parent_dir not in sys.path:
	sys.path.append(parent_dir)

# %%
from src.var_calculator import *

# %%
data = pd.read_csv('../data/processed/historical_stock_cleaned.csv', index_col=0, header=0)

returns = calculate_log_returns(data)
covariance = calculate_covariance_matrix(returns)

covariance.head(10)
# Out:
# c:\Users\sergi\Desktop\Proyecto_CV\var_engine\.venv\Lib\site-packages\pandas\core\internals\blocks.py:347: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#               ITX.MC_Close  AIR.PA_Close  SAN_Close  IBE.MC_Close  \
# ITX.MC_Close      0.096180      0.042864   0.042397      0.027843
# AIR.PA_Close      0.042864      0.145540   0.056506      0.030192
# SAN_Close         0.042397      0.056506   0.151234      0.043038
# IBE.MC_Close      0.027843      0.030192   0.043038      0.059935
# SIE.DE_Close      0.040666      0.065127   0.060777      0.033535
#
#               SIE.DE_Close
# ITX.MC_Close      0.040666
# AIR.PA_Close      0.065127
# SAN_Close         0.060777
# IBE.MC_Close      0.033535
# SIE.DE_Close      0.100096

# %%
returns.to_csv('../data/processed/log_returns.csv')
covariance.to_csv('../data/processed/covariance_matrix.csv')
