# %% [markdown]
# ## DAILY RETURNS

# %% [markdown]
# In this section we calculate daily logarithmic returns as well as the covariance matrix of said returns.

# %%
import sys
import os

parent_dir = os.path.abspath('..')

if parent_dir not in sys.path:
	sys.path.append(parent_dir)

# %%
from src.var_calculator import *

# %%
data = pd.read_csv('../data/processed/historical_stock_cleaned.csv', index_col=0, header=[0,1])

returns = calculate_log_returns(data)
covariance = calculate_covariance_matrix(returns)

covariance.head(10)
# Out:
# Ticker              SAN                                             IBE.MC  \
# Price              Open      High       Low     Close     Volume      Open
# Ticker Price
# SAN    Open    0.111635  0.094117  0.098623  0.083854  -0.234595  0.013457
#        High    0.094117  0.100078  0.096918  0.095599  -0.103743  0.009838
#        Low     0.098623  0.096918  0.112438  0.102676  -0.444406  0.010802
#        Close   0.083854  0.095599  0.102676  0.115199  -0.279827  0.005951
#        Volume -0.234595 -0.103743 -0.444406 -0.279827  48.524533 -0.070311
# IBE.MC Open    0.013457  0.009838  0.010802  0.005951  -0.070311  0.041791
#        High    0.012308  0.009816  0.009444  0.006616   0.022705  0.023177
#        Low     0.015948  0.013866  0.016285  0.012401  -0.037946  0.025049
#        Close   0.012848  0.014239  0.015941  0.015325  -0.045245  0.008631
#        Volume -0.155871 -0.192991 -0.200618 -0.171008   5.733303 -0.066503
#
# Ticker                                                   ...    ITX.MC  \
# Price              High       Low     Close      Volume  ...      Open
# Ticker Price                                             ...
# SAN    Open    0.012308  0.015948  0.012848   -0.155871  ...  0.021314
#        High    0.009816  0.013866  0.014239   -0.192991  ...  0.015072
#        Low     0.009444  0.016285  0.015941   -0.200618  ...  0.017942
#        Close   0.006616  0.012401  0.015325   -0.171008  ...  0.012005
#        Volume  0.022705 -0.037946 -0.045245    5.733303  ... -0.103168
# IBE.MC Open    0.023177  0.025049  0.008631   -0.066503  ...  0.018072
#        High    0.028678  0.022510  0.021021    0.131495  ...  0.006774
#        Low     0.022510  0.034716  0.022669   -0.108611  ...  0.009888
#        Close   0.021021  0.022669  0.035647    0.023746  ...  0.002466
#        Volume  0.131495 -0.108611  0.023746  104.283723  ... -0.023983
#
# Ticker                                                    AIR.PA            \
# Price              High       Low     Close     Volume      Open      High
# Ticker Price
# SAN    Open    0.028325  0.033909  0.033239  -0.123875  0.023020  0.030533
#        High    0.023602  0.026755  0.032519  -0.115834  0.015083  0.025639
#        Low     0.025058  0.031748  0.036895  -0.181822  0.015111  0.025570
#        Close   0.019884  0.023120  0.032758  -0.141565  0.008267  0.019795
#        Volume -0.014311 -0.122956 -0.086085  11.752425 -0.147971 -0.080396
# IBE.MC Open    0.014861  0.015404  0.010828  -0.041061  0.019727  0.014555
#        High    0.010594  0.009911  0.010250  -0.022871  0.009313  0.010515
#        Low     0.012566  0.014819  0.014898  -0.064892  0.013242  0.012259
#        Close   0.007496  0.009025  0.014171  -0.019295  0.000998  0.007725
#        Volume -0.056523 -0.213307 -0.258840  31.517989  0.041688 -0.031252
#
# Ticker
# Price               Low     Close     Volume
# Ticker Price
# SAN    Open    0.035611  0.039791  -0.191000
#        High    0.029279  0.041822  -0.137675
#        Low     0.034482  0.047172  -0.207031
#        Close   0.026582  0.043142  -0.157245
#        Volume -0.260034 -0.211909   6.435490
# IBE.MC Open    0.013505  0.007944  -0.034877
#        High    0.008668  0.007225   0.051904
#        Low     0.014295  0.012254  -0.042752
#        Close   0.008963  0.016036   0.016605
#        Volume -0.082266 -0.186147  21.494562
#
# [10 rows x 25 columns]
