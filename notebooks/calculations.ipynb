# %% [markdown]
# ## DAILY RETURNS

# %% [markdown]
# In this section we calculate daily logarithmic returns as well as the covariance matrix of said returns.

# %%
import sys
import os

parent_dir = os.path.abspath('..')

if parent_dir not in sys.path:
	sys.path.append(parent_dir)

# %%
from src.var_calculator import *

# %%
data = pd.read_csv('../data/processed/historical_stock_cleaned.csv', index_col=0, header=[0,1])

returns = calculate_log_returns(data)
covariance = calculate_covariance_matrix(returns)

covariance.head(10)
# Out:
# Ticker              SAN                                            IBE.MC  \
# Price              Open      High       Low     Close    Volume      Open
# Ticker Price
# SAN    Open    0.000443  0.000373  0.000391  0.000333 -0.000931  0.000053
#        High    0.000373  0.000397  0.000385  0.000379 -0.000412  0.000039
#        Low     0.000391  0.000385  0.000446  0.000407 -0.001764  0.000043
#        Close   0.000333  0.000379  0.000407  0.000457 -0.001110  0.000024
#        Volume -0.000931 -0.000412 -0.001764 -0.001110  0.192558 -0.000279
# IBE.MC Open    0.000053  0.000039  0.000043  0.000024 -0.000279  0.000166
#        High    0.000049  0.000039  0.000037  0.000026  0.000090  0.000092
#        Low     0.000063  0.000055  0.000065  0.000049 -0.000151  0.000099
#        Close   0.000051  0.000057  0.000063  0.000061 -0.000180  0.000034
#        Volume -0.000619 -0.000766 -0.000796 -0.000679  0.022751 -0.000264
#
# Ticker                                                 ...    ITX.MC  \
# Price              High       Low     Close    Volume  ...      Open
# Ticker Price                                           ...
# SAN    Open    0.000049  0.000063  0.000051 -0.000619  ...  0.000085
#        High    0.000039  0.000055  0.000057 -0.000766  ...  0.000060
#        Low     0.000037  0.000065  0.000063 -0.000796  ...  0.000071
#        Close   0.000026  0.000049  0.000061 -0.000679  ...  0.000048
#        Volume  0.000090 -0.000151 -0.000180  0.022751  ... -0.000409
# IBE.MC Open    0.000092  0.000099  0.000034 -0.000264  ...  0.000072
#        High    0.000114  0.000089  0.000083  0.000522  ...  0.000027
#        Low     0.000089  0.000138  0.000090 -0.000431  ...  0.000039
#        Close   0.000083  0.000090  0.000141  0.000094  ...  0.000010
#        Volume  0.000522 -0.000431  0.000094  0.413824  ... -0.000095
#
# Ticker                                                   AIR.PA            \
# Price              High       Low     Close    Volume      Open      High
# Ticker Price
# SAN    Open    0.000112  0.000135  0.000132 -0.000492  0.000091  0.000121
#        High    0.000094  0.000106  0.000129 -0.000460  0.000060  0.000102
#        Low     0.000099  0.000126  0.000146 -0.000722  0.000060  0.000101
#        Close   0.000079  0.000092  0.000130 -0.000562  0.000033  0.000079
#        Volume -0.000057 -0.000488 -0.000342  0.046637 -0.000587 -0.000319
# IBE.MC Open    0.000059  0.000061  0.000043 -0.000163  0.000078  0.000058
#        High    0.000042  0.000039  0.000041 -0.000091  0.000037  0.000042
#        Low     0.000050  0.000059  0.000059 -0.000258  0.000053  0.000049
#        Close   0.000030  0.000036  0.000056 -0.000077  0.000004  0.000031
#        Volume -0.000224 -0.000846 -0.001027  0.125071  0.000165 -0.000124
#
# Ticker
# Price               Low     Close    Volume
# Ticker Price
# SAN    Open    0.000141  0.000158 -0.000758
#        High    0.000116  0.000166 -0.000546
#        Low     0.000137  0.000187 -0.000822
#        Close   0.000105  0.000171 -0.000624
#        Volume -0.001032 -0.000841  0.025538
# IBE.MC Open    0.000054  0.000032 -0.000138
#        High    0.000034  0.000029  0.000206
#        Low     0.000057  0.000049 -0.000170
#        Close   0.000036  0.000064  0.000066
#        Volume -0.000326 -0.000739  0.085296
#
# [10 rows x 25 columns]
